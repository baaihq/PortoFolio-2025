# %% [markdown]
# <a href="https://colab.research.google.com/github/baaihq/PortoFolio-2025/blob/main/GetData_SNBP2025.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from bs4 import BeautifulSoup
import requests

# %%
# Mendefinisikan url untuk setiap Perguruan Tinggi yang akan diambil datanya.

# Daftar PTN AKADEMIK
url1 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=111'   #UNIVERSITAS SYIAH KUALA
url2 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=112'   #UNIVERSITAS MALIKUSSALEH
url3 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=113'   #UNIVERSITAS TEUKU UMAR
url4 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=114'   #UNIVERSITAS SAMUDRA
url5 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=115'   #ISBI ACEH
url6 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=121'   #UNIVERSITAS SUMATERA UTARA
url7 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=122'   #UNIVERSITAS NEGERI MEDAN
url8 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=131'   #UNIVERSITAS RIAU
url9 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=133'   #UNIVERSITAS MARITIM RAJA ALI HAJI
url10 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=141'  #UNIVERSITAS ANDALAS
url11 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=142'  #UNIVERSITAS NEGERI PADANG
url12 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=143'  #ISI PADANG PANJANG
url13 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=151'  #UNIVERSITAS JAMBI
url14 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=161'  #UNIVERSITAS BENGKULU
url15 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=171'  #UNIVERSITAS SRIWIJAYA
url16 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=181'  #UNIVERSITAS BANGKA BELITUNG
url17 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=191'  #UNIVERSITAS LAMPUNG
url18 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=192'  #INSTITUT TEKNOLOGI SUMATERA
url19 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=311'  #UNIVERSITAS SULTAN AGENG TIRTAYASA
url20 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=321'  #UNIVERSITAS INDONESIA
url21 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=323'  #UNIVERSITAS NEGERI JAKARTA
url22 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=324'  #UPN VETERAN JAKARTA
url23 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=329'  #UNIVERSITAS TERBUKA
url24 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=331'  #UNIVERSITAS SINGAPERBANGSA KARAWANG
url25 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=332'  #INSTITUT TEKNOLOGI BANDUNG
url26 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=333'  #UNIVERSITAS PADJADJARAN
url27 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=334'  #UNIVERSITAS PENDIDIKAN INDONESIA
url28 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=335'  #ISBI BANDUNG
url29 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=341'  #INSTITUT PERTANIAN BOGOR
url30 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=342'  #UNIVERSITAS SILIWANGI
url31 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=351'  #UNIVERSITAS JENDERAL SOEDIRMAN
url32 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=352'  #UNIVERSITAS TIDAR
url33 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=353'  #UNIVERSITAS SEBELAS MARET
url34 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=354'  #ISI SURAKARTA
url35 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=355'  #UNIVERSITAS DIPONEGORO
url36 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=356'  #UNIVERSITAS NEGERI SEMARANG
url37 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=361'  #UNIVERSITAS GADJAH MADA
url38 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=362'  #UNIVERSITAS NEGERI YOGYAKARTA
url39 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=363'  #UPN VETERAN YOGYAKARTA
url40 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=364'  #ISI YOGYAKARTA
url41 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=371'  #UNIVERSITAS JEMBER
url42 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=372'  #UNIVERSITAS BRAWIJAYA
url43 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=373'  #UNIVERSITAS NEGERI MALANG
url44 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=381'  #UNIVERSITAS AIRLANGGA
url45 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=382'  #INSTITUT TEKNOLOGI SEPULUH NOPEMBER
url46 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=383'  #UNIVERSITAS NEGERI SURABAYA
url47 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=384'  #UNIVERSITAS TRUNOJOYO MADURA
url48 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=385'  #UPN VETERAN JAWA TIMUR
url49 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=511'  #UNIVERSITAS TANJUNGPURA
url50 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=521'  #UNIVERSITAS PALANGKARAYA
url51 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=531'  #UNIVERSITAS LAMBUNG MANGKURAT
url52 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=541'  #UNIVERSITAS MULAWARMAN
url53 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=542'  #INSTITUT TEKNOLOGI KALIMANTAN
url54 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=551'  #UNIVERSITAS BORNEO TARAKAN
url55 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=611'  #UNIVERSITAS UDAYANA
url56 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=612'  #UNIVERSITAS PENDIDIKAN GANESHA
url57 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=613'  #ISI DENPASAR
url58 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=621'  #UNIVERSITAS MATARAM
url59 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=631'  #UNIVERSITAS NUSA CENDANA
url60 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=632'  #UNIVERSITAS TIMOR
url61 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=711'  #UNIVERSITAS HASANUDDIN
url62 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=712'  #UNIVERSITAS NEGERI MAKASSAR
url63 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=718'  #INSTITUT TEKNOLOGI BJ. HABIBIE SULAWESI SELATAN
url64 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=721'  #UNIVERSITAS SAM RATULANGI
url65 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=722'  #UNIVERSITAS NEGERI MANADO
url66 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=731'  #UNIVERSITAS TADULAKO
url67 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=741'  #UNIVERSITAS SULAWESI BARAT
url68 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=751'  #UNIVERSITAS HALUOLEO
url69 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=752'  #UNIVERSITAS NEGERI GORONTALO
url70 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=753'  #UNIVERSITAS SEMBILAN BELAS NOVEMBER KOLAKA
url71 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=811'  #UNIVERSITAS PATTIMURA
url72 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=821'  #UNIVERSITAS KHAIRUN
url73 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=911'  #UNIVERSITAS CENDERAWASIH
url74 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=912'  #UNIVERSITAS MUSAMUS MERAUKE
url75 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=913'  #ISBI TANAH PAPUA
url76 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=921'  #UNIVERSITAS PAPUA

# Daftar PT KIN
url77 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=116'  #UIN AR-RANIRY
url78 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=123'  #UIN SUMATERA UTARA
url79 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=124'  #UIN SYEKH ALI HASAN AHMAD ADDARY PADANGSIDIMPUAN
url80 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=132'  #UIN SULTAN SYARIF KASIM
url81 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=144'  #UIN IMAM BONJOL PADANG
url82 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=152'  #UIN SULTAN THAHA SAIFUDDIN JAMBI
url83 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=172'  #UIN RADEN FATAH
url84 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=193'  #UIN RADEN INTAN LAMPUNG
url85 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=194'  #UIN MAHMUD YUNUS BATUSANGKAR
url86 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=195'  #UIN SJECH M. DJAMIL DJAMBEK BUKITTINGGI
url87 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=312'  #UIN SULTAN MAULANA HASANUDDIN BANTEN
url88 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=322'  #UIN JAKARTA
url89 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=336'  #UIN SUNAN GUNUNG DJATI
url90 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=357'  #UIN WALISONGO
url91 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=358'  #UIN RADEN MAS SAID SURAKARTA
url92 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=365'  #UIN SUNAN KALIJAGA
url93 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=366'  #UIN PROFESOR KIAI HAJI SAIFUDDIN ZUHRI PURWOKERTO
url94 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=367'  #UIN SALATIGA
url95 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=368'  #UIN K.H. ABDURRAHMAN WAHID PEKALONGAN
url96 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=374'  #UIN MALANG
url97 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=386'  #UUIN SUNAN AMPEL SURABAYA
url98 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=532'  #UIN ANTASARI BANJARMASIN
url99 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=571'  #UIN SULTAN AJI MUHAMMAD IDRIS SAMARINDA
url100 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=622' #UIN MATARAM
url101 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=713' #UIN ALAUDDIN
url102 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=732' #UIN DATOKARAMA PALU


# Daftar PTN VOKASI
url103 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=221' #POLITEKNIK NEGERI LHOKSEUMAWE
url104 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=222' #POLITEKNIK NEGERI MEDAN
url105 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=231' #POLITEKNIK NEGERI BATAM
url106 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=232' #POLITEKNIK NEGERI BENGKALIS
url107 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=241' #POLITEKNIK NEGERI PADANG
url108 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=242' #POLITEKNIK PERTANIAN NEGERI PAYAKUMBUH
url109 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=271' #POLITEKNIK NEGERI SRIWIJAYA
url110 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=281' #POLITEKNIK MANUFAKTUR NEGERI BANGKA BELITUNG
url111 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=291' #POLITEKNIK NEGERI LAMPUNG
url112 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=421' #POLITEKNIK NEGERI JAKARTA
url113 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=422' #POLITEKNIK NEGERI MEDIA KREATIF
url114 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=431' #POLITEKNIK NEGERI BANDUNG
url115 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=432' #POLITEKNIK MANUFAKTUR BANDUNG
url116 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=433' #POLITEKNIK NEGERI INDRAMAYU
url117 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=434' #POLITEKNIK NEGERI SUBANG
url118 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=452' #POLITEKNIK NEGERI SEMARANG
url119 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=453' #POLITEKNIK NEGERI CILACAP
url120 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=454' #POLITEKNIK MARITIM NEGERI INDONESIA
url121 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=471' #POLITEKNIK NEGERI BANYUWANGI
url122 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=472' #POLITEKNIK NEGERI JEMBER
url123 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=473' #POLITEKNIK NEGERI MADIUN
url124 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=474' #POLITEKNIK NEGERI MALANG
url125 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=481' #POLITEKNIK PERKAPALAN NEGERI SURABAYA
url126 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=482' #POLITEKNIK ELEKTRONIKA NEGERI SURABAYA (PENS)
url127 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=483' #POLITEKNIK NEGERI MADURA
url128 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=515' #POLITEKNIK NEGERI PONTIANAK
url129 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=516' #POLITEKNIK NEGERI KETAPANG
url130 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=517' #POLITEKNIK NEGERI SAMBAS
url131 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=536' #POLITEKNIK NEGERI BANJARMASIN
url132 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=537' #POLITEKNIK NEGERI TANAH LAUT
url133 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=552' #POLITEKNIK NEGERI NUNUKAN
url134 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=561' #POLITEKNIK PERTANIAN NEGERI SAMARINDA
url135 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=562' #POLITEKNIK NEGERI SAMARINDA
url136 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=563' #POLITEKNIK NEGERI BALIKPAPAN
url137 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=617' #POLITEKNIK NEGERI BALI
url138 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=641' #POLITEKNIK NEGERI KUPANG
url139 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=642' #POLITEKNIK PERTANIAN NEGERI KUPANG
url140 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=716' #POLITEKNIK NEGERI UJUNG PANDANG
url141 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=717' #POLITEKNIK PERTANIAN NEGERI PANGKAJENE KEPULAUAN
url142 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=727' #POLITEKNIK NEGERI MANADO
url143 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=728' #POLITEKNIK NEGERI NUSA UTARA
url144 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=831' #POLITEKNIK NEGERI AMBON
url145 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=832' #POLITEKNIK PERIKANAN NEGERI TUAL
url146 = 'https://sidatagrun-public-1076756628210.asia-southeast2.run.app/ptn_sn.php?ptn=931' #POLITEKNIK NEGERI FAKFAK

# %%
# Mengirim permintaan GET ke URL dan menyimpan responsnya
for i in range(1, 147):
    exec(f"page{i} = requests.get(url{i})")

# %%
# Membuat objek BeautifulSoup untuk setiap halaman dari page1 hingga page146 dan menyimpannya dalam variabel soup1 hingga soup146.
for i in range(1, 147):
    exec(f"soup{i} = BeautifulSoup(page{i}.text, 'html')")

# %%
# Mencari tabel pertama dalam setiap objek BeautifulSoup dari soup1 hingga soup146 dan menyimpannya dalam variabel table1 hingga table146.
for i in range(1, 147):
    exec(f"table{i} = soup{i}.find_all('table')[0]")

# %%
# Mencari semua elemen th dalam setiap objek table dari table1 hingga table146 dan menyimpannya dalam variabel daftar_prodi1 hingga daftar_prodi146.
for i in range(1, 147):
    exec(f"daftar_prodi{i} = table{i}.find_all('th')")

# %%
# Mencari semua elemen th dalam tabel yang bersesuaian, mengambil teks dari setiap elemen tersebut, menghapus spasi ekstra, dan menyimpannya dalam variabel daftar_table_prodi11 hingga daftar_table_prodi146.
for i in range(1, 147):
    exec(f"daftar_table_prodi{i} = [title.text.strip() for title in daftar_prodi{i}]")

# Print daftar_table_prodi1 sebagai contoh tampilannya
print(daftar_table_prodi1)
# Out:
# ['NO', 'KODE', 'NAMA', 'JENJANG', 'DAYA TAMPUNG 2025', 'PEMINAT 2024', 'JENIS PORTOFOLIO']

# %%
import pandas as pd

# %%
# Membuat DataFrame baru dengan kolom yang sesuai dengan teks dari setiap elemen dalam daftar_table_prodi yang bersesuaian, dan menyimpan DataFrame tersebut dalam variabel df yang sesuai.
for i in range(1, 147):
    exec(f"df{i} = pd.DataFrame(columns = daftar_table_prodi{i})")

# %%
# Mengecek tampilan DataFrame1 (df1)
df1
# Out:
# Empty DataFrame
# Columns: [NO, KODE, NAMA, JENJANG, DAYA TAMPUNG 2025, PEMINAT 2024, JENIS PORTOFOLIO]
# Index: []

# %%
# Mencari semua elemen tr dalam setiap tabel dari table1 hingga table146 dan menyimpannya dalam variabel column_data1 hingga column_data101.
for i in range(1, 147):
    exec(f"column_data{i} = table{i}.find_all('tr')")

# %%
# Mengambil data dari setiap baris dalam column_data1 hingga column_data146, menghapus spasi ekstra, dan menambahkannya ke DataFrame yang sesuai.
for i in range(1, 147):
    for row in eval(f"column_data{i}[2:]"):
        row_data = row.find_all('td')
        individual_row_data = [data.text.strip() for data in row_data]
        length = len(eval(f"df{i}"))
        exec(f"df{i}.loc[length] = individual_row_data")

# %%
# Mengecek kembali tampilan df1
df1
# Out:
#     NO      KODE                     NAMA       JENJANG DAYA TAMPUNG 2025  \
# 0    1  11111001  PENDIDIKAN DOKTER HEWAN       Sarjana                72
# 1    2  11111002             TEKNIK SIPIL       Sarjana                84
# 2    3  11111003             TEKNIK MESIN       Sarjana                36
# 3    4  11111004             TEKNIK KIMIA       Sarjana                54
# 4    5  11111005               ARSITEKTUR       Sarjana                48
# ..  ..       ...                      ...           ...               ...
# 71  72  11113072                SEKRETARI  Diploma Tiga                12
# 72  73  11113073     MANAJEMEN PERUSAHAAN  Diploma Tiga                12
# 73  74  11113075                AKUNTANSI  Diploma Tiga                24
# 74  75  11113076   KEUANGAN DAN PERBANKAN  Diploma Tiga                24
# 75  76  11113077    MANAJEMEN INFORMATIKA  Diploma Tiga                24
#
#    PEMINAT 2024 JENIS PORTOFOLIO
# 0           350        Tidak Ada
# ...

# %%
# Mengecek tampilan df2
df2
# Out:
#     NO      KODE                                NAMA       JENJANG  \
# 0    1  11121001                        TEKNIK SIPIL       Sarjana
# 1    2  11121002                        TEKNIK MESIN       Sarjana
# 2    3  11121003                        TEKNIK KIMIA       Sarjana
# 3    4  11121004                      TEKNIK ELEKTRO       Sarjana
# 4    5  11121005                     TEKNIK INDUSTRI       Sarjana
# 5    6  11121006                  TEKNIK INFORMATIKA       Sarjana
# 6    7  11121007                   TEKNIK ARSITEKTUR       Sarjana
# 7    8  11121008                    AGROEKOTEKNOLOGI       Sarjana
# 8    9  11121009                          AGRIBISNIS       Sarjana
# 9   10  11121010                          AKUAKULTUR       Sarjana
# 10  11  11121011                          KEDOKTERAN       Sarjana
# 11  12  11121012                   PENDIDIKAN FISIKA       Sarjana
# 12  13  11121013                    PENDIDIKAN KIMIA       Sarjana
# ...

# %%
# Mengecek tampilan df101
df101
# Out:
#     NO      KODE                                 NAMA  JENJANG  \
# 0    1  17131001                           MATEMATIKA  Sarjana
# 1    2  17131003                                KIMIA  Sarjana
# 2    3  17131006  TEKNIK PERENCANAAN WILAYAH DAN KOTA  Sarjana
# 3    4  17131007                    TEKNIK ARSITEKTUR  Sarjana
# 4    5  17131008                      ILMU PETERNAKAN  Sarjana
# 5    6  17131015                     SISTEM INFORMASI  Sarjana
# 6    7  17131016                    PENDIDIKAN DOKTER  Sarjana
# 7    8  17131017                           ILMU HUKUM  Sarjana
# 8    9  17131018                          JURNALISTIK  Sarjana
# 9   10  17131019                            MANAJEMEN  Sarjana
# 10  11  17131024                            AKUNTANSI  Sarjana
# 11  12  17131025                         ILMU EKONOMI  Sarjana
# 12  13  17131031                         ILMU POLITIK  Sarjana
# 13  14  17131034                      ILMU KOMUNIKASI  Sarjana
# ...

# %%
# Mengecek tampilan df145
df145
# Out:
#    NO      KODE                                           NAMA  \
# 0   1  28322001                             TEKNOLOGI KELAUTAN
# 1   2  28322002                         BIOTEKNOLOGI PERIKANAN
# 2   3  28322003           MANAJEMEN REKAYASA PERIKANAN TANGKAP
# 3   4  28322004                         REKAYASA BUDIDAYA LAUT
# 4   5  28322005  MANAJEMEN REKAYASA PENGOLAHAN HASIL PERIKANAN
# 5   6  28322006                              AGROWISATA BAHARI
# 6   7  28323007                           AGRIBISNIS PERIKANAN
# 7   8  28323008                     TEKNOLOGI PENANGKAPAN IKAN
# 8   9  28323009                   TEKNOLOGI BUDIDAYA PERIKANAN
# 9  10  28323010                      TEKNOLOGI HASIL PERIKANAN
#
#            JENJANG DAYA TAMPUNG 2025 PEMINAT 2024 JENIS PORTOFOLIO
# 0  Sarjana Terapan                18           30        Tidak Ada
# 1  Sarjana Terapan                12           12        Tidak Ada
# 2  Sarjana Terapan                15           17        Tidak Ada
# ...

# %%
# Menambahkan nama Perguruan Tinggi di kolom pertama pada setiap DataFrame.
df1.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='UNIVERSITAS SYIAH KUALA')
df2.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='UNIVERSITAS MALIKUSSALEH')
df3.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='UNIVERSITAS TEUKU UMAR')
df4.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='UNIVERSITAS SAMUDRA')
df5.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='ISBI ACEH')
df6.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='UNIVERSITAS SUMATERA UTARA')
df7.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='UNIVERSITAS NEGERI MEDAN')
df8.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='UNIVERSITAS RIAU')
df9.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='UNIVERSITAS MARITIM RAJA ALI HAJI')
df10.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='UNIVERSITAS ANDALAS')
df11.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='UNIVERSITAS NEGERI PADANG')
df12.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='ISI PADANG PANJANG')
df13.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='UNIVERSITAS JAMBI')
df14.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='UNIVERSITAS BENGKULU')
df15.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='UNIVERSITAS SRIWIJAYA')
df16.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='UNIVERSITAS BANGKA BELITUNG')
df17.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='UNIVERSITAS LAMPUNG')
df18.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='INSTITUT TEKNOLOGI SUMATERA')
df19.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='UNIVERSITAS SULTAN AGENG TIRTAYASA')
df20.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='UNIVERSITAS INDONESIA')
df21.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='UNIVERSITAS NEGERI JAKARTA')
df22.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='UPN VETERAN JAKARTA')
df23.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='UNIVERSITAS TERBUKA')
df24.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='UNIVERSITAS SINGAPERBANGSA KARAWANG')
df25.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='INSTITUT TEKNOLOGI BANDUNG')
df26.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='UNIVERSITAS PADJADJARAN')
df27.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='UNIVERSITAS PENDIDIKAN INDONESIA')
df28.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='ISBI BANDUNG')
df29.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='INSTITUT PERTANIAN BOGOR')
df30.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='UNIVERSITAS SILIWANGI')
df31.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='UNIVERSITAS JENDERAL SOEDIRMAN')
df32.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='UNIVERSITAS TIDAR')
df33.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='UNIVERSITAS SEBELAS MARET')
df34.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='ISI SURAKARTA')
df35.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='UNIVERSITAS DIPONEGORO')
df36.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='UNIVERSITAS NEGERI SEMARANG')
df37.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='UNIVERSITAS GADJAH MADA')
df38.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='UNIVERSITAS NEGERI YOGYAKARTA')
df39.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='UPN VETERAN YOGYAKARTA')
df40.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='ISI YOGYAKARTA')
df41.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='UNIVERSITAS JEMBER')
df42.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='UNIVERSITAS BRAWIJAYA')
df43.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='UNIVERSITAS NEGERI MALANG')
df44.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='UNIVERSITAS AIRLANGGA')
df45.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='INSTITUT TEKNOLOGI SEPULUH NOPEMBER')
df46.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='UNIVERSITAS NEGERI SURABAYA')
df47.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='UNIVERSITAS TRUNOJOYO MADURA')
df48.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='UPN VETERAN JAWA TIMUR')
df49.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='UNIVERSITAS TANJUNGPURA')
df50.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='UNIVERSITAS PALANGKARAYA')
df51.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='UNIVERSITAS LAMBUNG MANGKURAT')
df52.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='UNIVERSITAS MULAWARMAN')
df53.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='INSTITUT TEKNOLOGI KALIMANTAN')
df54.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='UNIVERSITAS BORNEO TARAKAN')
df55.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='UNIVERSITAS UDAYANA')
df56.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='UNIVERSITAS PENDIDIKAN GANESHA')
df57.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='ISI DENPASAR')
df58.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='UNIVERSITAS MATARAM')
df59.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='UNIVERSITAS NUSA CENDANA')
df60.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='UNIVERSITAS TIMOR')
df61.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='UNIVERSITAS HASANUDDIN')
df62.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='UNIVERSITAS NEGERI MAKASSAR')
df63.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='INSTITUT TEKNOLOGI BJ. HABIBIE SULAWESI SELATAN')
df64.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='UNIVERSITAS SAM RATULANGI')
df65.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='UNIVERSITAS NEGERI MANADO')
df66.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='UNIVERSITAS TADULAKO')
df67.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='UNIVERSITAS SULAWESI BARAT')
df68.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='UNIVERSITAS HALUOLEO')
df69.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='UNIVERSITAS NEGERI GORONTALO')
df70.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='UNIVERSITAS SEMBILAN BELAS NOVEMBER KOLAKA')
df71.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='UNIVERSITAS PATTIMURA')
df72.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='UNIVERSITAS KHAIRUN')
df73.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='UNIVERSITAS CENDERAWASIH')
df74.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='UNIVERSITAS MUSAMUS MERAUKE')
df75.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='ISBI TANAH PAPUA')
df76.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='UNIVERSITAS PAPUA')
df77.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='UIN AR-RANIRY')
df78.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='UIN SUMATERA UTARA')
df79.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='UIN SYEKH ALI HASAN AHMAD ADDARY PADANGSIDIMPUAN')
df80.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='UIN SULTAN SYARIF KASIM')
df81.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='UIN IMAM BONJOL PADANG')
df82.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='UIN SULTAN THAHA SAIFUDDIN JAMBI')
df83.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='UIN RADEN FATAH')
df84.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='UIN RADEN INTAN LAMPUNG')
df85.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='UIN MAHMUD YUNUS BATUSANGKAR')
df86.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='UIN SJECH M. DJAMIL DJAMBEK BUKITTINGGI')
df87.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='UIN SULTAN MAULANA HASANUDDIN BANTEN')
df88.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='UIN JAKARTA')
df89.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='UIN SUNAN GUNUNG DJATI')
df90.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='UIN WALISONGO')
df91.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='UIN RADEN MAS SAID SURAKARTA')
df92.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='UIN SUNAN KALIJAGA')
df93.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='UIN PROFESOR KIAI HAJI SAIFUDDIN ZUHRI PURWOKERTO')
df94.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='UIN SALATIGA')
df95.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='UIN K.H. ABDURRAHMAN WAHID PEKALONGAN')
df96.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='UIN MALANG')
df97.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='UIN SUNAN AMPEL SURABAYA')
df98.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='UIN ANTASARI BANJARMASIN')
df99.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='UIN SULTAN AJI MUHAMMAD IDRIS SAMARINDA')
df100.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='UIN MATARAM')
df101.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='UIN ALAUDDIN')
df102.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='UIN DATOKARAMA PALU')
df103.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='POLITEKNIK NEGERI LHOKSEUMAWE')
df104.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='POLITEKNIK NEGERI MEDAN')
df105.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='POLITEKNIK NEGERI BATAM')
df106.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='POLITEKNIK NEGERI BENGKALIS')
df107.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='POLITEKNIK NEGERI PADANG')
df108.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='POLITEKNIK PERTANIAN NEGERI PAYAKUMBUH')
df109.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='POLITEKNIK NEGERI SRIWIJAYA')
df110.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='POLITEKNIK MANUFAKTUR NEGERI BANGKA BELITUNG')
df111.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='POLITEKNIK NEGERI LAMPUNG')
df112.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='POLITEKNIK NEGERI JAKARTA')
df113.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='POLITEKNIK NEGERI MEDIA KREATIF')
df114.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='POLITEKNIK NEGERI BANDUNG')
df115.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='POLITEKNIK MANUFAKTUR BANDUNG')
df116.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='POLITEKNIK NEGERI INDRAMAYU')
df117.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='POLITEKNIK NEGERI SUBANG')
df118.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='POLITEKNIK NEGERI SEMARANG')
df119.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='POLITEKNIK NEGERI CILACAP')
df120.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='POLITEKNIK MARITIM NEGERI INDONESIA')
df121.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='POLITEKNIK NEGERI BANYUWANGI')
df122.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='POLITEKNIK NEGERI JEMBER')
df123.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='POLITEKNIK NEGERI MADIUN')
df124.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='POLITEKNIK NEGERI MALANG')
df125.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='POLITEKNIK PERKAPALAN NEGERI SURABAYA')
df126.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='POLITEKNIK ELEKTRONIKA NEGERI SURABAYA (PENS)')
df127.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='POLITEKNIK NEGERI MADURA')
df128.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='POLITEKNIK NEGERI PONTIANAK')
df129.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='POLITEKNIK NEGERI KETAPANG')
df130.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='POLITEKNIK NEGERI SAMBAS')
df131.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='POLITEKNIK NEGERI BANJARMASIN')
df132.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='POLITEKNIK NEGERI TANAH LAUT')
df133.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='POLITEKNIK NEGERI NUNUKAN')
df134.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='POLITEKNIK PERTANIAN NEGERI SAMARINDA')
df135.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='POLITEKNIK NEGERI SAMARINDA')
df136.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='POLITEKNIK NEGERI BALIKPAPAN')
df137.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='POLITEKNIK NEGERI BALI')
df138.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='POLITEKNIK NEGERI KUPANG')
df139.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='POLITEKNIK PERTANIAN NEGERI KUPANG')
df140.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='POLITEKNIK NEGERI UJUNG PANDANG')
df141.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='POLITEKNIK PERTANIAN NEGERI PANGKAJENE KEPULAUAN')
df142.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='POLITEKNIK NEGERI MANADO')
df143.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='POLITEKNIK NEGERI NUSA UTARA')
df144.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='POLITEKNIK NEGERI AMBON')
df145.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='POLITEKNIK PERIKANAN NEGERI TUAL')
df146.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='POLITEKNIK NEGERI FAKFAK')

# %%
# Mengecek kembali tampilan df1
df1
# Out:
#     NO    NAMA PERGURUAN TINGGI      KODE                     NAMA  \
# 0    1  UNIVERSITAS SYIAH KUALA  11111001  PENDIDIKAN DOKTER HEWAN
# 1    2  UNIVERSITAS SYIAH KUALA  11111002             TEKNIK SIPIL
# 2    3  UNIVERSITAS SYIAH KUALA  11111003             TEKNIK MESIN
# 3    4  UNIVERSITAS SYIAH KUALA  11111004             TEKNIK KIMIA
# 4    5  UNIVERSITAS SYIAH KUALA  11111005               ARSITEKTUR
# ..  ..                      ...       ...                      ...
# 71  72  UNIVERSITAS SYIAH KUALA  11113072                SEKRETARI
# 72  73  UNIVERSITAS SYIAH KUALA  11113073     MANAJEMEN PERUSAHAAN
# 73  74  UNIVERSITAS SYIAH KUALA  11113075                AKUNTANSI
# 74  75  UNIVERSITAS SYIAH KUALA  11113076   KEUANGAN DAN PERBANKAN
# 75  76  UNIVERSITAS SYIAH KUALA  11113077    MANAJEMEN INFORMATIKA
#
#          JENJANG DAYA TAMPUNG 2025 PEMINAT 2024 JENIS PORTOFOLIO
# 0        Sarjana                72          350        Tidak Ada
# ...

# %%
# Mengecek tampilan df20
df20
# Out:
#     NO  NAMA PERGURUAN TINGGI      KODE                                 NAMA  \
# 0    1  UNIVERSITAS INDONESIA  13211001                    PENDIDIKAN DOKTER
# 1    2  UNIVERSITAS INDONESIA  13211002               PENDIDIKAN DOKTER GIGI
# 2    3  UNIVERSITAS INDONESIA  13211003                           MATEMATIKA
# 3    4  UNIVERSITAS INDONESIA  13211004                               FISIKA
# 4    5  UNIVERSITAS INDONESIA  13211005                                KIMIA
# ..  ..                    ...       ...                                  ...
# 74  75  UNIVERSITAS INDONESIA  13213073     ADMINISTRASI ASURANSI & AKTUARIA
# 75  76  UNIVERSITAS INDONESIA  13213074                  HUBUNGAN MASYARAKAT
# 76  77  UNIVERSITAS INDONESIA  13213075                   PERIKLANAN KREATIF
# 77  78  UNIVERSITAS INDONESIA  13213076                            AKUNTANSI
# 78  79  UNIVERSITAS INDONESIA  13213077  ADMINISTRASI KEUANGAN DAN PERBANKAN
#
# ...

# %%
# Mengecek tampilan df101
df101
# Out:
#     NO NAMA PERGURUAN TINGGI      KODE                                 NAMA  \
# 0    1          UIN ALAUDDIN  17131001                           MATEMATIKA
# 1    2          UIN ALAUDDIN  17131003                                KIMIA
# 2    3          UIN ALAUDDIN  17131006  TEKNIK PERENCANAAN WILAYAH DAN KOTA
# 3    4          UIN ALAUDDIN  17131007                    TEKNIK ARSITEKTUR
# 4    5          UIN ALAUDDIN  17131008                      ILMU PETERNAKAN
# 5    6          UIN ALAUDDIN  17131015                     SISTEM INFORMASI
# 6    7          UIN ALAUDDIN  17131016                    PENDIDIKAN DOKTER
# 7    8          UIN ALAUDDIN  17131017                           ILMU HUKUM
# 8    9          UIN ALAUDDIN  17131018                          JURNALISTIK
# 9   10          UIN ALAUDDIN  17131019                            MANAJEMEN
# 10  11          UIN ALAUDDIN  17131024                            AKUNTANSI
# ...

# %%
# Mengecek tampilan df146
df146
# Out:
#   NO     NAMA PERGURUAN TINGGI      KODE  \
# 0  1  POLITEKNIK NEGERI FAKFAK  29312001
# 1  2  POLITEKNIK NEGERI FAKFAK  29312007
# 2  3  POLITEKNIK NEGERI FAKFAK  29312008
# 3  4  POLITEKNIK NEGERI FAKFAK  29313002
# 4  5  POLITEKNIK NEGERI FAKFAK  29313003
# 5  6  POLITEKNIK NEGERI FAKFAK  29313004
# 6  7  POLITEKNIK NEGERI FAKFAK  29313005
# 7  8  POLITEKNIK NEGERI FAKFAK  29313006
#
#                                                NAMA          JENJANG  \
# 0  TEKNOLOGI REKAYASA KONSTRUKSI JALAN DAN JEMBATAN  Sarjana Terapan
# 1                           AKUNTANSI SEKTOR PUBLIK  Sarjana Terapan
# 2                 PENGELOLAAN AGRIBISNIS PERKEBUNAN  Sarjana Terapan
# 3                                    TEKNIK LISTRIK     Diploma Tiga
# 4                                      TEKNIK SIPIL     Diploma Tiga
# 5                             MANAJEMEN INFORMATIKA     Diploma Tiga
# 6                                     AGRO INDUSTRI     Diploma Tiga
# ...

# %%
# Menghapus kolom pertama dari setiap DataFrame.
for i in range(1, 147):
    globals()[f'df{i}'] = globals()[f'df{i}'].drop(globals()[f'df{i}'].columns[0], axis=1)

# Merubah kolom judul "NAMA" menjadi "PROGRAM STUDI".
for i in range(1, 147):
    exec(f"df{i} = df{i}.rename(columns={{'NAMA': 'PROGRAM STUDI'}})")

# %%
# Mengecek kembali tampilan df1
df1
# Out:
#       NAMA PERGURUAN TINGGI      KODE            PROGRAM STUDI       JENJANG  \
# 0   UNIVERSITAS SYIAH KUALA  11111001  PENDIDIKAN DOKTER HEWAN       Sarjana
# 1   UNIVERSITAS SYIAH KUALA  11111002             TEKNIK SIPIL       Sarjana
# 2   UNIVERSITAS SYIAH KUALA  11111003             TEKNIK MESIN       Sarjana
# 3   UNIVERSITAS SYIAH KUALA  11111004             TEKNIK KIMIA       Sarjana
# 4   UNIVERSITAS SYIAH KUALA  11111005               ARSITEKTUR       Sarjana
# ..                      ...       ...                      ...           ...
# 71  UNIVERSITAS SYIAH KUALA  11113072                SEKRETARI  Diploma Tiga
# 72  UNIVERSITAS SYIAH KUALA  11113073     MANAJEMEN PERUSAHAAN  Diploma Tiga
# 73  UNIVERSITAS SYIAH KUALA  11113075                AKUNTANSI  Diploma Tiga
# 74  UNIVERSITAS SYIAH KUALA  11113076   KEUANGAN DAN PERBANKAN  Diploma Tiga
# 75  UNIVERSITAS SYIAH KUALA  11113077    MANAJEMEN INFORMATIKA  Diploma Tiga
#
# ...

# %%
# Mengecek tampilan df20
df20
# Out:
#     NAMA PERGURUAN TINGGI      KODE                        PROGRAM STUDI  \
# 0   UNIVERSITAS INDONESIA  13211001                    PENDIDIKAN DOKTER
# 1   UNIVERSITAS INDONESIA  13211002               PENDIDIKAN DOKTER GIGI
# 2   UNIVERSITAS INDONESIA  13211003                           MATEMATIKA
# 3   UNIVERSITAS INDONESIA  13211004                               FISIKA
# 4   UNIVERSITAS INDONESIA  13211005                                KIMIA
# ..                    ...       ...                                  ...
# 74  UNIVERSITAS INDONESIA  13213073     ADMINISTRASI ASURANSI & AKTUARIA
# 75  UNIVERSITAS INDONESIA  13213074                  HUBUNGAN MASYARAKAT
# 76  UNIVERSITAS INDONESIA  13213075                   PERIKLANAN KREATIF
# 77  UNIVERSITAS INDONESIA  13213076                            AKUNTANSI
# 78  UNIVERSITAS INDONESIA  13213077  ADMINISTRASI KEUANGAN DAN PERBANKAN
#
#          JENJANG DAYA TAMPUNG 2025 PEMINAT 2024 JENIS PORTOFOLIO
# ...

# %%
# Membuat list dari semua DataFrame
dfs = [globals()[f'df{i}'] for i in range(1, 147)]

# Mencetak tampilan dari setiap DataFrame dalam list
for i, df in enumerate(dfs, start=1):
    print(f"=== df{i} ===")
    from google.colab import files
    print(df)
# Out:
# Streaming output truncated to the last 5000 lines.
# 19   UNIVERSITAS UDAYANA  16111020                     INFORMATIKA
# 20   UNIVERSITAS UDAYANA  16111021             TEKNOLOGI INFORMASI
# 21   UNIVERSITAS UDAYANA  16111022                     FISIOTERAPI
# 22   UNIVERSITAS UDAYANA  16111023                   ILMU KELAUTAN
# 23   UNIVERSITAS UDAYANA  16111024              ARSITEKTUR LANSKAP
# 24   UNIVERSITAS UDAYANA  16111025  MANAJEMEN SUMBER DAYA PERAIRAN
# 25   UNIVERSITAS UDAYANA  16111026                 KEDOKTERAN GIGI
# 26   UNIVERSITAS UDAYANA  16111027               TEKNIK LINGKUNGAN
# 27   UNIVERSITAS UDAYANA  16111028                 TEKNIK INDUSTRI
# 28   UNIVERSITAS UDAYANA  16111029                       ARKEOLOGI
# 29   UNIVERSITAS UDAYANA  16111030              ANTROPOLOGI BUDAYA
# 30   UNIVERSITAS UDAYANA  16111031                    ILMU SEJARAH
# 31   UNIVERSITAS UDAYANA  16111032                      ILMU HUKUM
# ...

# %%
# Menyimpan DataFrame ke file CSV
for i in range(1, 147):
    exec(f"df{i}.to_csv(f'df{i}.csv', index = False)")
